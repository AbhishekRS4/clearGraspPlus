# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from imageio import imread, imwrite

# %%
file_img_1 = "/home/abhishek/Desktop/RUG/ai_master_thesis/clearGraspPlus/eval_depth_completion/results_resnet50_psa//exp-023/input-image/000000016-rgb.png"
file_img_2 = "/home/abhishek/Desktop/RUG/ai_master_thesis/clearGraspPlus/eval_depth_completion/results_resnet50_psa//exp-023/gt-depth/000000016-gt-depth-rgb.png"
file_img_3 = "/home/abhishek/Desktop/RUG/ai_master_thesis/clearGraspPlus/eval_depth_completion/results_resnet50_psa//exp-023/input-depth/000000016-modified-input-depth-rgb.png"
file_img_4 = "/home/abhishek/Desktop/RUG/ai_master_thesis/clearGraspPlus/eval_depth_completion/results_resnet50_psa//exp-023/output-depth/000000016-output-depth-rgb.png"

# %%
output_file = "/home/abhishek/Desktop/RUG/ai_master_thesis/camera_setup_images/depth-test-object-3-16-resnet50_psa.png"

# %%
img_1 = imread(file_img_1)
img_2 = imread(file_img_2)
img_3 = imread(file_img_3)
img_4 = imread(file_img_4)
# Out:
# /tmp/ipykernel_25383/1465432180.py:1: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img_1 = imread(file_img_1)
# /tmp/ipykernel_25383/1465432180.py:2: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img_2 = imread(file_img_2)
# /tmp/ipykernel_25383/1465432180.py:3: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img_3 = imread(file_img_3)
# ...

# %%
img_1.shape, img_2.shape, img_3.shape, img_4.shape
# Out:
# ((144, 256, 3), (144, 256, 3), (144, 256, 3), (144, 256, 3))

# %%
plt.imshow(img_1)

# %%
plt.imshow(img_2)

# %%
plt.imshow(img_3)

# %%
plt.imshow(img_4)

# %%
img_stacked = np.zeros((img_1.shape[0], 4*img_1.shape[1], img_1.shape[2]), dtype=np.uint8)

# %%
img_stacked[:, :img_1.shape[1], :] = img_1
img_stacked[:, img_1.shape[1]:2*img_1.shape[1], :] = img_2
img_stacked[:, 2*img_1.shape[1]:3*img_1.shape[1], :] = img_3
img_stacked[:, 3*img_1.shape[1]:, :] = img_4

# %%
plt.imshow(img_stacked)

# %%
imwrite(output_file, img_stacked)
