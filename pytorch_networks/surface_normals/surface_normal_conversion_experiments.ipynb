# %%
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
from utils import utils

# %%
sample_sn_exr_file = "/home/abhishek/Desktop/RUG/ai_master_thesis/cleargrasp-dataset-test-val/synthetic-val/cup-with-waves-val/camera-normals/000000006-cameraNormals.exr"

# %%
img_sn = utils.exr_loader(sample_sn_exr_file, ndim=3)
img_sn = np.transpose(img_sn, axes=[1, 2, 0])

# %%
np.min(img_sn), np.max(img_sn)
# Out:
# (-0.9897461, 0.99902344)

# %%
img_sn.dtype
# Out:
# dtype('float32')

# %%
img_sn.shape
# Out:
# (576, 1024, 3)

# %%
plt.imshow(img_sn)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
img_sn_rgb = (img_sn + 1) * 255 / 2

# %%
img_sn_rgb = img_sn_rgb.astype(np.uint8)

# %%
plt.imshow(img_sn_rgb)

# %%
sample_nyu_sn_file = "/home/abhishek/Downloads/nyu_normals_gt_rgb/00027.png"

# %%
from imageio import imread

# %%
img_sn_nyu = imread(sample_nyu_sn_file)
# Out:
# /tmp/ipykernel_271735/1723536250.py:1: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img_sn_nyu = imread(sample_nyu_sn_file)

# %%
img_sn_nyu.shape
# Out:
# (480, 640, 3)

# %%
img_sn_nyu.dtype
# Out:
# dtype('uint8')

# %%
plt.imshow(img_sn_nyu)

# %%
np.min(img_sn_nyu), np.max(img_sn_nyu)
# Out:
# (0, 254)

# %%
img_sn_nyu.shape
# Out:
# (480, 640, 3)

# %%
img_sn_nyu_normalized = (2. * img_sn_nyu / 255.) - 1.

# %%
img_sn_nyu_normalized = img_sn_nyu_normalized.astype(np.float32)

# %%
np.min(img_sn_nyu_normalized), np.max(img_sn_nyu_normalized)
# Out:
# (-1.0, 0.99215686)

# %%
plt.imshow(img_sn_nyu_normalized)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
img_sn_nyu_recovered = (img_sn_nyu_normalized + 1.) * 255. / 2.

# %%
img_sn_nyu_recovered = img_sn_nyu_recovered.astype(np.uint8)

# %%
plt.imshow(img_sn_nyu_recovered)

# %%
utils.exr_saver("temp.exr", np.transpose(img_sn_nyu_normalized, axes=[2, 0, 1]))

# %%
temp = utils.exr_loader("/home/abhishek/Downloads/nyu_normals_gt_exr/00027-cameraNormals.exr")

# %%
plt.imshow(np.transpose(temp, axes=[1, 2, 0]))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
"00005.png".split(".")[0]+"-cameraNormals.exr"
# Out:
# '00005-cameraNormals.exr'
