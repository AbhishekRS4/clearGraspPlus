# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from imageio import imread, imwrite

# %%
file_vis_orig = "/home/abhishek/Desktop/RUG/ai_master_thesis/camera_setup_images/sur-real-test-34-resnet50_psa.png"

# %%
img_vis_orig = imread(file_vis_orig)

# %%
plt.figure()
plt.imshow(img_vis_orig)

# %%
img_vis_orig.shape
# Out:
# (260, 1034, 3)

# %%
target_width = int(img_vis_orig.shape[1] * .75)

# %%
target_width
# Out:
# 775

# %%
plt.figure()
plt.imshow(img_vis_orig[:, :target_width, :])

# %%
imwrite(file_vis_orig, img_vis_orig[:, :target_width, :])
